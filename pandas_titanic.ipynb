# %% [markdown]
# # Importing Pandas

# %%
import pandas as pd

# Round to two decimal places in Pandas dataframe
pd.options.display.float_format = '{:.2f}'.format

# %% [markdown]
# # Loading Titanic Dataset

# %%
url = 'https://raw.githubusercontent.com/edaehn/python_tutorials/main/titanic/train.csv'

# %%
titanic_df = pd.read_csv(url)

# %%
titanic_df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male 22.00      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female 38.00      1
# 2                               Heikkinen, Miss. Laina  female 26.00      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female 35.00      1
# 4                             Allen, Mr. William Henry    male 35.00      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male 27.00      0
# 887                       Graham, Miss. Margaret Edith  female 19.00      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male 26.00      0
# 890                                Dooley, Mr. Patrick    male 32.00      0
#
#      Parch            Ticket  Fare Cabin Embarked
# 0        0         A/5 21171  7.25   NaN        S
# 1        0          PC 17599 71.28   C85        C
# 2        0  STON/O2. 3101282  7.92   NaN        S
# 3        0            113803 53.10  C123        S
# 4        0            373450  8.05   NaN        S
# ..     ...               ...   ...   ...      ...
# 886      0            211536 13.00   NaN        S
# 887      0            112053 30.00   B42        S
# 888      2        W./C. 6607 23.45   NaN        S
# 889      0            111369 30.00  C148        C
# 890      0            370376  7.75   NaN        Q
#
# [891 rows x 12 columns]

# %% [markdown]
# #  Data Exploration

# %% [markdown]
# ## The head() and tail()

# %%
titanic_df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male 22.00      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female 38.00      1
# 2                             Heikkinen, Miss. Laina  female 26.00      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female 35.00      1
# 4                           Allen, Mr. William Henry    male 35.00      0
#
#    Parch            Ticket  Fare Cabin Embarked
# 0      0         A/5 21171  7.25   NaN        S
# 1      0          PC 17599 71.28   C85        C
# 2      0  STON/O2. 3101282  7.92   NaN        S
# 3      0            113803 53.10  C123        S
# 4      0            373450  8.05   NaN        S

# %%
titanic_df.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %% [markdown]
# ## The describe()

# %%
titanic_df.describe()
# Out:
#        PassengerId  Survived  Pclass    Age  SibSp  Parch   Fare
# count       891.00    891.00  891.00 714.00 891.00 891.00 891.00
# mean        446.00      0.38    2.31  29.70   0.52   0.38  32.20
# std         257.35      0.49    0.84  14.53   1.10   0.81  49.69
# min           1.00      0.00    1.00   0.42   0.00   0.00   0.00
# 25%         223.50      0.00    2.00  20.12   0.00   0.00   7.91
# 50%         446.00      0.00    3.00  28.00   0.00   0.00  14.45
# 75%         668.50      1.00    3.00  38.00   1.00   0.00  31.00
# max         891.00      1.00    3.00  80.00   8.00   6.00 512.33

# %% [markdown]
# ## The value_counts()

# %%
titanic_df["Age"].value_counts(ascending=True)
# Out:
# 74.00     1
# 14.50     1
# 70.50     1
# 12.00     1
# 36.50     1
#          ..
# 30.00    25
# 19.00    25
# 18.00    26
# 22.00    27
# 24.00    30
# Name: Age, Length: 88, dtype: int64

# %% [markdown]
# ## The corr()

# %%
titanic_df.corr()
# Out:
#              PassengerId  Survived  Pclass   Age  SibSp  Parch  Fare
# PassengerId         1.00     -0.01   -0.04  0.04  -0.06  -0.00  0.01
# Survived           -0.01      1.00   -0.34 -0.08  -0.04   0.08  0.26
# Pclass             -0.04     -0.34    1.00 -0.37   0.08   0.02 -0.55
# Age                 0.04     -0.08   -0.37  1.00  -0.31  -0.19  0.10
# SibSp              -0.06     -0.04    0.08 -0.31   1.00   0.41  0.16
# Parch              -0.00      0.08    0.02 -0.19   0.41   1.00  0.22
# Fare                0.01      0.26   -0.55  0.10   0.16   0.22  1.00

# %% [markdown]
# ## The info()

# %%
titanic_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %% [markdown]
# # Data Cleansing

# %%
# The size of loaded dataset
titanic_df.shape
# Out:
# (891, 12)

# %% [markdown]
# ## Finding missing values

# %%
# Finding all columns with NaN values:
titanic_df.isna().any()
# Out:
# PassengerId    False
# Survived       False
# Pclass         False
# Name           False
# Sex            False
# Age             True
# SibSp          False
# Parch          False
# Ticket         False
# Fare           False
# Cabin           True
# Embarked        True
# dtype: bool

# %%
# With the sum() function, we see the total number of rows 
# with the NaN values for each column.
titanic_df.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
titanic_df.isnull().any()
# Out:
# PassengerId    False
# Survived       False
# Pclass         False
# Name           False
# Sex            False
# Age             True
# SibSp          False
# Parch          False
# Ticket         False
# Fare           False
# Cabin           True
# Embarked        True
# dtype: bool

# %%
# Selecting all columns with NaN values
titanic_df[titanic_df.columns[titanic_df.isna().any()]]
# Out:
#       Age Cabin Embarked
# 0    22.0   NaN        S
# 1    38.0   C85        C
# 2    26.0   NaN        S
# 3    35.0  C123        S
# 4    35.0   NaN        S
# ..    ...   ...      ...
# 886  27.0   NaN        S
# 887  19.0   B42        S
# 888   NaN   NaN        S
# 889  26.0  C148        C
# 890  32.0   NaN        Q
#
# [891 rows x 3 columns]

# %% [markdown]
# ## Removing missing values

# %%
# Removing all rows with NaN
titanic_df.dropna(axis=0, how='any', inplace=True)

# The size of the resulting dataset
titanic_df.shape
# Out:
# (183, 12)

# %% [markdown]
# # Accessing Data

# %% [markdown]
# ## The bracket-based indexing operator

# %%
# Get the only columns "Name", "Sex", "Age" of the first five rows
titanic_df[["Name", "Sex", "Age"]][:4]
# Out:
#                                                  Name  Sex   Age
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  NaN  38.0
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  NaN  35.0
# 6                             McCarthy, Mr. Timothy J  NaN  54.0
# 10                    Sandstrom, Miss. Marguerite Rut  NaN   4.0

# %% [markdown]
# ## Accessing data by the key

# %%
titanic_df.iloc[:5]
# Out:
#     PassengerId  Survived  Pclass  \
# 1             2         1       1
# 3             4         1       1
# 6             7         0       1
# 10           11         1       3
# 11           12         1       1
#
#                                                  Name  Sex   Age  SibSp  \
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  NaN  38.0      1
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  NaN  35.0      1
# 6                             McCarthy, Mr. Timothy J  NaN  54.0      0
# 10                    Sandstrom, Miss. Marguerite Rut  NaN   4.0      1
# 11                           Bonnell, Miss. Elizabeth  NaN  58.0      0
#
#     Parch    Ticket     Fare Cabin Embarked  Age_squared
# 1       0  PC 17599  71.2833   C85        C       1444.0
# 3       0    113803  53.1000  C123        S       1225.0
# 6       0     17463  51.8625   E46        S       2916.0
# 10      1   PP 9549  16.7000    G6        S         16.0
# 11      0    113783  26.5500  C103        S       3364.0

# %% [markdown]
# ## Integer-location based indexing

# %%
# The most senior passenger
titanic_df.iloc[[titanic_df['Age'].argmax()]]
# Out:
#      PassengerId  Survived  Pclass                                  Name  Sex  \
# 630          631         1       1  Barkworth, Mr. Algernon Henry Wilson  NaN
#
#       Age  SibSp  Parch Ticket  Fare Cabin Embarked  Age_squared
# 630  80.0      0      0  27042  30.0   A23        S       6400.0

# %%
# Paid the highest fair
titanic_df.iloc[[titanic_df['Fare'].argmax()]]
# Out:
#      PassengerId  Survived  Pclass                                Name  Sex  \
# 679          680         1       1  Cardeza, Mr. Thomas Drake Martinez  NaN
#
#       Age  SibSp  Parch    Ticket      Fare        Cabin Embarked  Age_squared
# 679  36.0      0      1  PC 17755  512.3292  B51 B53 B55        C       1296.0

# %% [markdown]
# ## Working with columns

# %%
# To access a specific column, you can use 
# the square brackets notation
titanic_df['Age']
# Out:
# 1      38.0
# 3      35.0
# 6      54.0
# 10      4.0
# 11     58.0
#        ...
# 871    47.0
# 872    33.0
# 879    56.0
# 887    19.0
# 889    26.0
# Name: Age, Length: 183, dtype: float64

# %%
# Selecting multiple columns
titanic_df[['Age', 'Fare']]
# Out:
#       Age  Fare
# 0   22.00  7.25
# 1   38.00 71.28
# 2   26.00  7.92
# 3   35.00 53.10
# 4   35.00  8.05
# ..    ...   ...
# 886 27.00 13.00
# 887 19.00 30.00
# 888   NaN 23.45
# 889 26.00 30.00
# 890 32.00  7.75
#
# [891 rows x 2 columns]

# %% [markdown]
# ## Conditional filtering

# %%
# Use the filter function to select only the rows 
# where 'Age' is not null
filtered_df = titanic_df[titanic_df['Age'].notnull()]

# %%
# where 'Age' is older than 30
titanic_df[titanic_df['Age'] > 30]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 11            12         1       1
# 21            22         1       2
# ..           ...       ...     ...
# 862          863         1       1
# 867          868         0       1
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# 21                               Beesley, Mr. Lawrence    male  34.0      0
# ..                                                 ...     ...   ...    ...
# 862  Swift, Mrs. Frederick Joel (Margaret Welles Ba...  female  48.0      0
# 867               Roebling, Mr. Washington Augustus II    male  31.0      0
# 871   Beckwith, Mrs. Richard Leonard (Sallie Monypeny)  female  47.0      1
# 872                           Carlsson, Mr. Frans Olof    male  33.0      0
# 879      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)  female  56.0      0
#
#      Parch    Ticket     Fare        Cabin Embarked
# 1        0  PC 17599  71.2833          C85        C
# 3        0    113803  53.1000         C123        S
# 6        0     17463  51.8625          E46        S
# 11       0    113783  26.5500         C103        S
# 21       0    248698  13.0000          D56        S
# ..     ...       ...      ...          ...      ...
# 862      0     17466  25.9292          D17        S
# 867      0  PC 17590  50.4958          A24        S
# 871      1     11751  52.5542          D35        S
# 872      0       695   5.0000  B51 B53 B55        S
# 879      1     11767  83.1583          C50        C
#
# [114 rows x 12 columns]

# %% [markdown]
# # Modifying the data

# %%
# To create a new column
titanic_df['Age_squared'] = titanic_df['Age'] ** 2

# %%
titanic_df['Age_squared']
# Out:
# 1      1444.0
# 3      1225.0
# 6      2916.0
# 10       16.0
# 11     3364.0
#         ...
# 871    2209.0
# 872    1089.0
# 879    3136.0
# 887     361.0
# 889     676.0
# Name: Age_squared, Length: 183, dtype: float64

# %%
# To drop a column
titanic_df.drop('Age_squared', axis=1)
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# 871   Beckwith, Mrs. Richard Leonard (Sallie Monypeny)  female  47.0      1
# 872                           Carlsson, Mr. Frans Olof    male  33.0      0
# 879      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)  female  56.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 889                              Behr, Mr. Karl Howell    male  26.0      0
#
#      Parch    Ticket     Fare        Cabin Embarked
# 1        0  PC 17599  71.2833          C85        C
# 3        0    113803  53.1000         C123        S
# 6        0     17463  51.8625          E46        S
# 10       1   PP 9549  16.7000           G6        S
# 11       0    113783  26.5500         C103        S
# ..     ...       ...      ...          ...      ...
# 871      1     11751  52.5542          D35        S
# 872      0       695   5.0000  B51 B53 B55        S
# 879      1     11767  83.1583          C50        C
# 887      0    112053  30.0000          B42        S
# 889      0    111369  30.0000         C148        C
#
# [183 rows x 12 columns]

# %% [markdown]
# # Data sorting

# %%
# Who paid too few
titanic_df.sort_values('Fare').head()
# Out:
#      PassengerId  Survived  Pclass  \
# 806          807         0       1
# 263          264         0       1
# 872          873         0       1
# 715          716         0       3
# 699          700         0       3
#
#                                            Name  Sex   Age  SibSp  Parch  \
# 806                      Andrews, Mr. Thomas Jr  NaN  39.0      0      0
# 263                       Harrison, Mr. William  NaN  40.0      0      0
# 872                    Carlsson, Mr. Frans Olof  NaN  33.0      0      0
# 715  Soholt, Mr. Peter Andreas Lauritz Andersen  NaN  19.0      0      0
# 699    Humblen, Mr. Adolf Mathias Nicolai Olsen  NaN  42.0      0      0
#
#      Ticket  Fare        Cabin Embarked  Age_squared
# 806  112050  0.00          A36        S       1521.0
# 263  112059  0.00          B94        S       1600.0
# 872     695  5.00  B51 B53 B55        S       1089.0
# 715  348124  7.65        F G73        S        361.0
# 699  348121  7.65        F G63        S       1764.0

# %%
# Who paid too much
titanic_df.sort_values('Fare', ascending=False).head()
# Out:
#      PassengerId  Survived  Pclass                                Name  Sex  \
# 737          738         1       1              Lesurer, Mr. Gustave J  NaN
# 679          680         1       1  Cardeza, Mr. Thomas Drake Martinez  NaN
# 88            89         1       1          Fortune, Miss. Mabel Helen  NaN
# 27            28         0       1      Fortune, Mr. Charles Alexander  NaN
# 438          439         0       1                   Fortune, Mr. Mark  NaN
#
#       Age  SibSp  Parch    Ticket      Fare        Cabin Embarked  Age_squared
# 737  35.0      0      0  PC 17755  512.3292         B101        C       1225.0
# 679  36.0      0      1  PC 17755  512.3292  B51 B53 B55        C       1296.0
# 88   23.0      3      2     19950  263.0000  C23 C25 C27        S        529.0
# 27   19.0      3      2     19950  263.0000  C23 C25 C27        S        361.0
# 438  64.0      1      4     19950  263.0000  C23 C25 C27        S       4096.0

# %% [markdown]
# # Data Transformation

# %%
# Use the map function to convert the 'Sex' column to a numeric value
titanic_df['Sex'] = titanic_df['Sex'].map({'male': 0, 'female': 1})

# %%
titanic_df['Sex'][:10]
# Out:
# 1     1
# 3     1
# 6     0
# 10    1
# 11    1
# 21    0
# 23    0
# 27    0
# 52    1
# 54    0
# Name: Sex, dtype: int64

# %% [markdown]
# # Visualising data

# %% [markdown]
# ## Bar plots

# %%
# The pyplot is a module in the matplotlib library in Python 
# that provides functions for creating various plots and charts. 
import matplotlib.pyplot as plt

# Load the Titanic dataset
# titanic_df = pd.read_csv('titanic.csv')

# Group the data by class and calculate the number of survivors in each class
survival_by_class = titanic_df.groupby('Pclass')['Survived'].sum()

# Sort the values by the number of survivors
survival_by_class = survival_by_class.sort_values()

# Create a bar plot of the number of survivors by class
survival_by_class.plot.bar()

# Add a title and labels to the plot
plt.title('Number of survivors by class')
plt.xlabel('Class')
plt.ylabel('Number of survivors')

# Show the plot
plt.show()

# %% [markdown]
# ## The scatter plot of age vs. fare

# %%
# Create a scatter plot of age vs fare
titanic_df.plot.scatter(x='Age', y='Fare')

# Add a title and labels to the plot
plt.title('Age vs Fare')
plt.xlabel('Age')
plt.ylabel('Fare')

# Show the plot
plt.show()

# %%
import seaborn as sns
sns.scatterplot(x='Age', y='Fare', hue='Sex', data=titanic_df)

# Add a title and labels to the plot
plt.title('Age vs Fare')
plt.xlabel('Age')
plt.ylabel('Fare')

# Show the plot
plt.show()

# %% [markdown]
# ## Histograms

# %%
# Create a histogram of the ages of the passengers
titanic_df['Age'].plot.hist()

# Add a title and labels to the plot
plt.title('Age distribution of passengers')
plt.xlabel('Age')
plt.ylabel('Number of passengers')

# Show the plot
plt.show()

# %% [markdown]
# ## Box plots

# %%
# Create a box plot of the fare by class
titanic_df.boxplot(column='Fare', by='Pclass')

# Add a title and labels to the plot
plt.title('Fare by class')
plt.xlabel('Class')
plt.ylabel('Fare')

# Show the plot
plt.show()
# Out:
# /usr/local/lib/python3.8/dist-packages/matplotlib/cbook/__init__.py:1376: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   X = np.atleast_1d(X.T if isinstance(X, np.ndarray) else np.asarray(X))

# %% [markdown]
# ## Heatmaps

# %%
# Draw a heatmap function from the seaborn library to identify patterns in survival rates by class and gender.
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load the Titanic dataset
# titanic_df = pd.read_csv('titanic.csv')

# Pivot the data to create a survival rate by class and gender
pivoted = titanic_df.pivot_table(index='Pclass', columns='Sex', values='Survived', aggfunc='mean')

# Create a heatmap of the survival rate by class and gender
sns.heatmap(pivoted, cmap='Reds')

# Add a title and labels to the plot
plt.title('Survival rate by class and gender')
plt.xlabel('Gender')
plt.ylabel('Class')

# Show the plot
plt.show()

# %% [markdown]
# # Statistical Analysis

# %% [markdown]
# ## Descriptive statistics

# %%
# Calculate Mean
print(titanic_df['Fare'].mean())

# Calculate Median
print(titanic_df['Fare'].median())

# Calculate Sum
print(titanic_df['Fare'].sum())

# Calculate Standard Deviation
print(titanic_df['Fare'].std())

# Calculate the minimum value
print(titanic_df['Fare'].min())

# Calculate the maximum value
print(titanic_df['Fare'].max())
# Out:
# 32.204207968574636
# 14.4542
# 28693.9493
# 49.6934285971809
# 0.0
# 512.3292

# %% [markdown]
# ## Correlation

# %%
correlation = titanic_df['Fare'].corr(titanic_df['Age'])
print(correlation)
# Out:
# 0.09606669176903888

# %% [markdown]
# # Data Aggregation

# %%
titanic_df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %% [markdown]
# ## Data Grouping

# %%
grouped = titanic_df.groupby(by='Pclass')['Fare'].mean()
print(grouped)
# Out:
# Pclass
# 1    88.683228
# 2    18.444447
# 3    11.027500
# Name: Fare, dtype: float64

# %% [markdown]
# # Pivot table

# %%
pd.pivot_table(
    data=titanic_df,
    values="Fare", 
    index=["Pclass", "Sex"], 
    columns=["Survived"], 
    aggfunc=["count", "mean"], 
    fill_value=None, 
    margins=True, 
    dropna=True, 
    margins_name='All', 
    observed=False,
    sort=True
)
# Out:
#               count             mean
# Survived          0    1  All      0      1    All
# Pclass Sex
# 1      female     3   91   94 110.60 105.98 106.13
#        male      77   45  122  62.89  74.64  67.23
# 2      female     6   70   76  18.25  22.29  21.97
#        male      91   17  108  19.49  21.10  19.74
# 3      female    72   72  144  19.77  12.46  16.12
#        male     300   47  347  12.20  15.58  12.66
# All             549  342  891  22.12  48.40  32.20

# %% [markdown]
# # Crosstab

# %%
summarised_table = pd.crosstab(titanic_df['Survived'], titanic_df['Pclass'], normalize=True)
print(summarised_table)
# Out:
# Pclass      1    2    3
# Survived
# 0        0.09 0.11 0.42
# 1        0.15 0.10 0.13
